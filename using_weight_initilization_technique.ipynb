# %%
import tensorflow
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import make_moons

from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_decision_regions

# %%
x, y = make_moons(n_samples=1000, noise=0.25, random_state=2)

# %%
plt.scatter(x[:,0],x[:,1], c=y)
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
# here create a model do not use weight initilization

model1 = Sequential()
model1.add(Dense(10, input_dim=2, activation='relu'))
model1.add(Dense(10, activation='relu'))
model1.add(Dense(1, activation='sigmoid'))
model1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model1.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test), verbose=1)
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6489 - loss: 0.6660 - val_accuracy: 0.8200 - val_loss: 0.6428
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8023 - loss: 0.6433 - val_accuracy: 0.8750 - val_loss: 0.6102
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8532 - loss: 0.6066 - val_accuracy: 0.8800 - val_loss: 0.5696
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8669 - loss: 0.5648 - val_accuracy: 0.8900 - val_loss: 0.5245
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8409 - loss: 0.5360 - val_accuracy: 0.8800 - val_loss: 0.4741
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8668 - loss: 0.4764 - val_accuracy: 0.8950 - val_loss: 0.4264
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8594 - loss: 0.4405 - val_accuracy: 0.9000 - val_loss: 0.3831
# Epoch 8/100
# ...

# %%
model1_weights = model1.get_weights()

# %%
model1_weights
# Out:
# [array([[-0.00261532, -0.9543936 , -0.809385  , -0.7093974 ,  0.7934405 ,
#           0.2785807 , -0.6129831 ,  0.17547503, -0.67511445, -0.99661654],
#         [ 0.6933841 , -0.38521427,  0.73164546,  0.15729214,  0.05839405,
#          -0.6405269 , -0.25624683,  0.84329   , -0.29928204, -0.4203062 ]],
#        dtype=float32),
#  array([ 0.46437764, -0.17981583, -0.1715495 , -0.01782931, -0.76080626,
#          0.3041586 ,  0.594251  ,  0.35369667, -0.09141073, -0.15638676],
#        dtype=float32),
#  array([[ 0.74120367,  0.49495527,  0.23244183,  0.3308107 ,  0.20137765,
#           0.4042129 ,  0.13347486,  0.8159091 ,  0.5901253 ,  0.5380338 ],
#         [ 0.93393147,  0.40814006, -0.58078665, -0.99891925,  0.32069573,
#          -1.0826402 , -1.1651056 ,  0.8935553 ,  1.2092277 ,  0.3995658 ],
#         [ 0.44526747,  0.6794538 , -0.23521188, -0.22348663, -0.28404316,
#          -0.19821398,  0.32327393,  0.3888425 ,  0.3011829 ,  0.1271963 ],
# ...

# %%
# here create a model do not use weight initilization

model2 = Sequential()
model2.add(Dense(10, input_dim=2, activation='relu', kernel_initializer = 'he_normal'))
model2.add(Dense(10, activation='relu', kernel_initializer = 'he_normal'))
model2.add(Dense(1, activation='sigmoid'))
model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model2.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test), verbose=1)
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.3377 - loss: 0.8662 - val_accuracy: 0.3350 - val_loss: 0.7991
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4362 - loss: 0.7617 - val_accuracy: 0.5550 - val_loss: 0.6864
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6167 - loss: 0.6595 - val_accuracy: 0.6550 - val_loss: 0.5866
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6527 - loss: 0.5808 - val_accuracy: 0.8750 - val_loss: 0.5102
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8042 - loss: 0.5337 - val_accuracy: 0.8800 - val_loss: 0.4576
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8508 - loss: 0.4692 - val_accuracy: 0.8900 - val_loss: 0.4129
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8415 - loss: 0.4378 - val_accuracy: 0.8900 - val_loss: 0.3783
# Epoch 8/100
# ...

# %%
# without using weight initializer model decision region
plot_decision_regions(x, y, clf = model1, legend =2)
plt.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step

# %%
# using weight initializer model decision region
plot_decision_regions(x, y, clf = model1, legend =2)
plt.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
